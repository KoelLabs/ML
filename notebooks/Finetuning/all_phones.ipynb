# %%
import os
import sys

sys.path.append(os.path.join("..", ".."))
from scripts.data_loaders.common import show_hf_sample
from datasets import Dataset, load_dataset

phone_examples_ds = load_dataset("KoelLabs/private-phoneme-examples")["train"]  # type: ignore
# Show a sample from the dataset

# %%
show_hf_sample(phone_examples_ds[2])
# Out:
# IPA: ðeəwɒzəʊnlɪeɪkəɒvɡɹaʊndɒvðætəndfɑːðəwɪəhædəntɡɒtɹuːmtəmuːvjuːnəʊhiːwɒzbaɪɪŋeɪlɒtɒvkɒbzəndjuːkʊdənttɜːnfɔːɔːfaɪvɪnwʌnmedəʊ
# Metadata: {'phoneme': 'd'}
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
