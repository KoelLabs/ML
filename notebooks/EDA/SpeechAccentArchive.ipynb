# %%
import sys
sys.path.append('../..')

from scripts.data_loaders.common import show_sample
from scripts.data_loaders.SpeechAccent import SpeechAccentDataset

import pandas as pd

from IPython.display import clear_output
clear_output()

# %%
dataset = SpeechAccentDataset(include_speaker_info=True, include_text=True)

# %%
show_sample(dataset[288])
# Out:
# IPA: pliːzɪkʌlstɛlʌæʃkhɜ˞tɔːbʁɪŋðiːzɪθɪŋzwɪθhɜ˞fʁʌmðztɔːʁsɪkspbuːnsɒfʁʃnəʊpiːzfɪvʌθɪkslæbzɔːfbluːtʃiːzɪnmeɪbæsnækfɔːʁhjɜ˞bʁʌðɜ˞bɒbwiːlsʌniːdʌsmɔːlplæstɪksneɪkɪndʌbiːɡtɔɪfʁɒɡfɔːʁðʌkʌdzʃɛkɪnskuːpθʌsɪθɪŋzɪntəʊθʁɪʁdbæɡzɪnwjuːɪlɡəʊmiːðɜ˞wɛnzdiːæθɒtʁeɪnsteɪʃʌn
# ...

# %%
show_sample(dataset[1237])
# Out:
# IPA: pliːzɪkʌlstɛlʌæʃkhɝtɔːbʀɪŋðiːzɪθɪŋzwɪθhɝʀʌmðztɔːʀsɪkspbuːnsɒfʀʃnəʊpiːzfɪvʌθɪkslæbzɔːfbluːtʃiːzɪnmeɪbæsnæɔːʀhjɝbʀʌðɝbɒwiːlsʌniːɾʌsmɔːlplæstɪksneɪʌndʌbɪɡtɔɪfʀɒɡfɔːʀðʌkʌdzʃɛkɛnskuːpθʌsɪθɪŋzɪntəʊθʀɪʀdbæɡzɛndwjuːɪlɡəʊmiːðɝwɛnzdiːæθɒtʀeɪnsteɪʃʌn
# ...
