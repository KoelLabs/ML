# %%
import sys
sys.path.append('../..')

from scripts.data_loaders.common import show_sample
from scripts.data_loaders.DoReCo import DoReCoDataset

from IPython.display import clear_output
clear_output()

# %%
all_speakers = DoReCoDataset(split='all', include_speaker_info=True, include_text=True)
speaker3 = DoReCoDataset(split='EN03', include_speaker_info=True, include_text=True)

# %%
show_sample(all_speakers[0])
# Out:
# IPA: aɪwɒzfɔːwenaɪkʌmwiːkʌmtəwʌnkɒtɪdʒðəfɜːstmuːvfɹɒmsɪtɪŋbɔːn
# Metadata: {'id': 'T004', 'name': 'doreco_sout3282_mc_english_kent02_b_part1', 'spk_code': 'EN01', 'spk_age': 85, 'spk_age_c': 'approximate', 'spk_sex': 'm', 'rec_date': 1975, 'rec_date_c': 'certain', 'genre': 'personal narrative', 'genre_stim': 'na', 'gloss': 'all', 'transl': 'English', 'sound_quality': 'medium', 'background_noise': 'punctual', 'word_tokens': 2381, 'word_tokens_core': 2381, 'extended': 'no'} I was four when I come we come to one cottage the first move from Sittingbourne
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
show_sample(speaker3[10])
# Out:
# IPA: welɒvkɔːswiːɔːlnəʊðætðeəwɒzeɪsiːkɹətfɔːtɹævəlɪnðəʊzɡɹeɪtbɪɡstæljənhɔːsɪzɪnðəwɒtaɪmiːntəseɪɪnðəbɹiːdɪŋtaɪmðeɪwʊdəntɡəʊəlɒŋwɪθenɪɔːdnəɹɪpɜːsənjuːnəʊ
# Metadata: {'id': 'T007', 'name': 'doreco_sout3282_mc_english_kent03_b_part1', 'spk_code': 'EN03', 'spk_age': 87, 'spk_age_c': 'approximate', 'spk_sex': 'm', 'rec_date': 1976, 'rec_date_c': 'certain', 'genre': 'personal narrative', 'genre_stim': 'na', 'gloss': 'all', 'transl': 'English', 'sound_quality': 'medium', 'background_noise': 'punctual', 'word_tokens': 2106, 'word_tokens_core': 2106, 'extended': 'no'} Well of course we all know that there was a secret for travelling those great big stallionhorses in the what I mean to say in the breedingtime they wouldn't go along with any ordinary person you know
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
for i, sample in enumerate(all_speakers): # type: ignore
    if len(sample[1]) / 16_000 < 1:
        print(i)
        show_sample(sample)
# Out:
# 49
# IPA: lethɪmduːðæt
# Metadata: {'id': 'T004', 'name': 'doreco_sout3282_mc_english_kent02_b_part1', 'spk_code': 'EN01', 'spk_age': 85, 'spk_age_c': 'approximate', 'spk_sex': 'm', 'rec_date': 1975, 'rec_date_c': 'certain', 'genre': 'personal narrative', 'genre_stim': 'na', 'gloss': 'all', 'transl': 'English', 'sound_quality': 'medium', 'background_noise': 'punctual', 'word_tokens': 2381, 'word_tokens_core': 2381, 'extended': 'no'} Let him do that
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 241
# IPA: aɪdəʊntnəʊwɒtɪtswɜː
# Metadata: {'id': 'T005', 'name': 'doreco_sout3282_mc_english_kent02_b_part2', 'spk_code': 'EN01', 'spk_age': 85, 'spk_age_c': 'approximate', 'spk_sex': 'm', 'rec_date': 1975, 'rec_date_c': 'certain', 'genre': 'personal narrative', 'genre_stim': 'na', 'gloss': 'all', 'transl': 'English', 'sound_quality': 'medium', 'background_noise': 'punctual', 'word_tokens': 2350, 'word_tokens_core': 2350, 'extended': 'no'} I don't know what it's worth
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 248
# IPA: nðeɪwɒzeɪpenɪ
# Metadata: {'id': 'T005', 'name': 'doreco_sout3282_mc_english_kent02_b_part2', 'spk_code': 'EN01', 'spk_age': 85, 'spk_age_c': 'approximate', 'spk_sex': 'm', 'rec_date': 1975, 'rec_date_c': 'certain', 'genre': 'personal narrative', 'genre_stim': 'na', 'gloss': 'all', 'transl': 'English', 'sound_quality': 'medium', 'background_noise': 'punctual', 'word_tokens': 2350, 'word_tokens_core': 2350, 'extended': 'no'} n they was a penny
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 262
# IPA: dɪdəntmeɪknəʊfʌ
# Metadata: {'id': 'T005', 'name': 'doreco_sout3282_mc_english_kent02_b_part2', 'spk_code': 'EN01', 'spk_age': 85, 'spk_age_c': 'approximate', 'spk_sex': 'm', 'rec_date': 1975, 'rec_date_c': 'certain', 'genre': 'personal narrative', 'genre_stim': 'na', 'gloss': 'all', 'transl': 'English', 'sound_quality': 'medium', 'background_noise': 'punctual', 'word_tokens': 2350, 'word_tokens_core': 2350, 'extended': 'no'} Didn't make no fuss
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
