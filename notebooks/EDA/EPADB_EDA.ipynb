# %%
import sys
sys.path.append('../..')

from scripts.data_loaders.common import show_sample
from scripts.data_loaders.EpaDB import EpaDBDataset

from IPython.display import clear_output
clear_output()

# %%
train = EpaDBDataset(split='train', include_timestamps=True, include_speaker_info=True, include_text=True)

# %%
show_sample(train[0])
# Out:
# IPA: oɹnaɪsɹɛdtɔɪ
# Metadata: [('o', 13760, 16000), ('ɹ', 16000, 18240), ('n', 18240, 20000), ('aɪ', 20000, 22560), ('s', 22560, 25440), ('ɹ', 25440, 27040), ('ɛ', 27040, 28000), ('d', 28000, 30560), ('t', 30560, 31565), ('ɔɪ', 31565, 34400)] {'speaker_id': 'spkr109'}  our nice red toy
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
