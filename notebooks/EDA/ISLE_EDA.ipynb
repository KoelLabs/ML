# %%
import sys

sys.path.append("../..")

from scripts.data_loaders.common import show_sample
from scripts.data_loaders.ISLE import ISLEDataset

from IPython.display import clear_output

clear_output()

# %%
dataset = ISLEDataset(
    split="all",
    include_timestamps=True,
    include_ambiguous_flags=True,
    include_text=True,
    include_speaker_info=True,
)

# %%
show_sample(dataset[0])
# Out:
# IPA: aɪˈsɛˈdwaɪˈtnɒˈtbeɪˈts
# Metadata: [('aɪˈ', 1400000, 2000000), ('s', 2000000, 3200000), ('ɛˈ', 3200000, 3800000), ('d', 3800000, 4700000), ('w', 4700000, 6100000), ('aɪˈ', 6100000, 9000000), ('t', 9000000, 9900000), ('n', 9900000, 10700000), ('ɒˈ', 10700000, 11500000), ('t', 11500000, 11900000), ('b', 11900000, 12500000), ('eɪˈ', 12500000, 15000000), ('t', 15000000, 16900000), ('s', 15000000, 16900000)] {'speaker_id': 'BLOCKD01_01', 'session': 'SESS0003', 'sub_dir': 'S0083/ISLEDAT1', 'native_language': 'Italian', 'comments': None} I SAID WHITE NOT BAIT [('aɪˈ', False, 'AY1'), ('s', False, 'S'), ('ɛˈ', False, 'EH1'), ('d', False, 'D'), ('w', False, 'W'), ('aɪˈ', False, 'AY1'), ('t', False, 'T'), ('n', False, 'N'), ('ɒˈ', False, 'OH1'), ('t', False, 'T'), ('b', False, 'B'), ('eɪˈ', False, 'EY1'), ('t', False, 'T'), ('s', False, 'S')]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
