# %%
import sys

sys.path.append("../..")

from scripts.data_loaders.common import show_sample
from scripts.data_loaders.ISLE import ISLE

from IPython.display import clear_output

clear_output()

# %%
train = ISLE(
    split="all",
    include_timestamps=True,
    include_ambiguous_flags=True,
    include_text=True,
    include_speaker_info=True,
)

# %%
show_sample(train[0])
# Out:
# IPA: aɪsɛdθɹunɒtðoʊ
# Metadata: [('aɪ', 1700000, 3200000), ('s', 3200000, 4400000), ('ɛ', 4400000, 5400000), ('d', 5400000, 6600000), ('θ', 8000000, 10200000), ('ɹ', 10200000, 10800000), ('u', 10800000, 13900000), ('n', 14800000, 15600000), ('ɒ', 15600000, 16600000), ('t', 16600000, 19100000), ('ð', 19100000, 19800000), ('oʊ', 19800000, 23700000)] {'speaker_id': 'BLOCKD01_15', 'session': 'SESS0021', 'sub_dir': 'S0083/ISLEDAT1'} I SAID THROUGH NOT THOUGH  [('aɪ', 'F', 'AY'), ('s', 'F', 'S'), ('ɛ', 'F', 'EH'), ('d', 'F', 'D'), ('θ', 'F', 'TH'), ('ɹ', 'F', 'R'), ('u', 'F', 'UW'), ('n', 'F', 'N'), ('ɒ', 'F', 'OH'), ('t', 'F', 'T'), ('ð', 'F', 'DH'), ('oʊ', 'F', 'OW')]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
